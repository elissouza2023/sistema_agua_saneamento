# %% [markdown]
# # 1: Imports e configurações

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Machine Learning / Estatística
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# Configurações visuais
plt.style.use("ggplot")

# Exibir todas as colunas
pd.set_option('display.max_columns', None)

# Exibir números com 2 casas decimais
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # 2: Carregar o CSV gerado

# %%
# Baixando a planilha mais recente do GitHub
url = "https://raw.githubusercontent.com/elissouza2023/sistema_agua_saneamento/main/data/Dados - Estudo Micromedição.xlsx"
response = requests.get(url)
response.raise_for_status()  # Garante que o download deu certo

print("Planilha baixada com sucesso!")
# Out:
# Planilha baixada com sucesso!

# %% [markdown]
# # 3: Limpeza e criação de data

# %% [markdown]
# # 4: Salvando os dados

# %% [markdown]
# # 5: Criando gráficos comparativos
